# %%
#!pip install -r requirements.txt
#!pip install pyfim==6.28

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import sparse

from itertools import permutations,combinations
from collections import Counter

from fim import arules, fpgrowth

# %%
path = "..../"
articles = pd.read_csv(path + "articles.csv")
customers = pd.read_csv(path + "customers.csv")
transactions = pd.read_csv(path + "transactions_train.csv")

# %%
# set an article name that contains colour scheme and graphical appearance
articles["article_name"] = articles["colour_group_name"] + " " + articles["graphical_appearance_name"] + " " + articles["prod_name"]

# %%
# merge relevant article data into transactions
transactions_merged = pd.merge(transactions[["customer_id", "article_id", "t_dat"]],
                      articles[["article_id","article_name", "product_type_name", "product_group_name"]], on="article_id")

# %% [markdown]
# Analysis by article granularity

# %%
# remove multiple identical items bought in the same transaction
transactions_merged2=transactions_merged.drop_duplicates(["t_dat", "customer_id", "article_name"])

# %%
transactions_merged2.head()
# Out:
#                                          customer_id  article_id       t_dat  \
# 0  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001  2018-09-20
# 1  3681748607f3287d2c3a65e00bb5fb153de30e9becf158...   663713001  2018-09-20
# 2  4ef5967ff17bf474bffebe5b16bd54878e1d4105f7b4ed...   663713001  2018-09-20
# 3  6b7b10d2d47516c82a6f97332478dab748070f09693f09...   663713001  2018-09-20
# 4  8ac137752bbe914aa4ae6ad007a9a0c5b67a1ab2b2d474...   663713001  2018-09-20
#
#                            article_name product_type_name product_group_name
# 0  Black Solid Atlanta Push Body Harlow    Underwear body          Underwear
# 1  Black Solid Atlanta Push Body Harlow    Underwear body          Underwear
# 2  Black Solid Atlanta Push Body Harlow    Underwear body          Underwear
# 3  Black Solid Atlanta Push Body Harlow    Underwear body          Underwear
# 4  Black Solid Atlanta Push Body Harlow    Underwear body          Underwear

# %%
# group articles bought by the same person on the same day to obtain orders
article_name_df=transactions_merged2.groupby(["t_dat", "customer_id"],as_index=False)["article_name"].agg(','.join)
article_name_df["article_name"]= article_name_df["article_name"].str.split(",", n = 100, expand = False)

# %%
# convert orders into array for apriori algorithm
apriori_array = article_name_df["article_name"].to_numpy()

# %%
#Apriori report 
report_colnames = {
    'a': 'support_itemset_absolute',
    's': 'support_itemset_relative',
    'S': 'support_itemset_relative_pct',
    'b': 'support_bodyset_absolute',
    'x': 'support_bodyset_relative',
    'X': 'support_bodyset_relative_pct',
    'h': 'support_headitem_absolute',
    'y': 'support_headitem_relative',
    'Y': 'support_headitem_relative_pct',
    'c': 'confidence',
    'C': 'confidence_pct',
    'l': 'lift',
    'L': 'lift_pct',
    'e': 'evaluation',
    'E': 'evaluation_pct',
    'Q': 'xx',
    'S': 'support_emptyset',
    }

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 2 # minimum length
zmax = 2 # maximum length 
report = "asCl"
algo = "ap" # "fp" or "ap"

# %%
# uncomment either to check documentation for apriori or fpgrowth algorithms

#?arules
#?fpgrowth

# %%
# start apriori (or fpgrowth) store results in a result dataframe
if algo == "ap":
    result = arules(apriori_array, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(apriori_array, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (88954, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(10))
# Out:
#                                                 consequent  \
# 0                     Black Solid Jade HW Skinny Denim TRS
# 1                 Dark Blue Solid Jade HW Skinny Denim TRS
# 67  Dark Green Other structure Simple as That Triangle Top
# 66  Dark Green Other structure Simple as that Cheeky Tanga
# 7                Light Blue Solid Jade HW Skinny Denim TRS
# 6                 Dark Blue Solid Jade HW Skinny Denim TRS
# 55         Red Other structure Simple as That Triangle Top
# 56         Red Other structure Simple as that Cheeky Tanga
# 2                               Black Solid Luna skinny RW
# 3                                Blue Denim Luna skinny RW
#
#                                                    antecedent  \
# 0                 (Dark Blue Solid Jade HW Skinny Denim TRS,)
# 1                     (Black Solid Jade HW Skinny Denim TRS,)
# 67  (Dark Green Other structure Simple as that Cheeky Tanga,)
# 66  (Dark Green Other structure Simple as That Triangle Top,)
# 7                 (Dark Blue Solid Jade HW Skinny Denim TRS,)
# 6                (Light Blue Solid Jade HW Skinny Denim TRS,)
# 55         (Red Other structure Simple as that Cheeky Tanga,)
# 56         (Red Other structure Simple as That Triangle Top,)
# 2                                (Blue Denim Luna skinny RW,)
# 3                               (Black Solid Luna skinny RW,)
#
#     support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 0                       7125                  0.000785       18.541168
# 1                       7125                  0.000785       16.445850
# 67                      6982                  0.000769       64.433370
# 66                      6982                  0.000769       71.742704
# 7                       5954                  0.000656       15.493911
# 6                       5954                  0.000656       18.283995
# 55                      5914                  0.000651       60.445626
# 56                      5914                  0.000651       46.895567
# 2                       5786                  0.000637       16.796818
# 3                       5786                  0.000637       15.500844
#
#           lift
# 0    38.860014
# 1    38.860014
# 67  601.178109
# 66  601.178109
# 7    43.203379
# 6    43.203379
# 55  435.220918
# 56  435.220918
# 2    40.859999
# 3    40.859999

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(10))
# Out:
#                                             consequent  \
# 69325               Black Melange SPAM fancy shorts BB
# 84902                     Turquoise Solid Carp cut-out
# 69327     Light Grey Front print Apollo casual s/s tee
# 69329            White Front print Beach price tanktop
# 69360                 White All over pattern HAPPY TEE
# 69361                        Grey Front print ANDY L/S
# 69364        Greenish Khaki Front print ANDY FANCY L/S
# 84938                 Light Blue Denim SKINNY BASIC 89
# 84939  Greenish Khaki All over pattern Cleopatra tunic
# 64880                  Dark Green Solid Papi Chulo Top
#
#                                                  antecedent  \
# 69325  (Light Green Placement print Apollo casual s/s tee,)
# 84902                (Light Purple Stripe Sharkfin bottom,)
# 69327  (Light Green Placement print Apollo casual s/s tee,)
# 69329  (Light Green Placement print Apollo casual s/s tee,)
# 69360              (White All over pattern BOAZ PRICE L/S,)
# 69361              (White All over pattern BOAZ PRICE L/S,)
# 69364              (White All over pattern BOAZ PRICE L/S,)
# 84938                        (Light Pink Check Lexi Shirt,)
# 84939                        (Light Pink Check Lexi Shirt,)
# 64880                       (White Solid Tom Denim Shorts,)
#
#        support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 69325                         5              5.506499e-07        5.376344
# 84902                         5              5.506499e-07        5.494505
# 69327                         5              5.506499e-07        5.376344
# 69329                         5              5.506499e-07        5.376344
# 69360                         5              5.506499e-07        5.000000
# 69361                         5              5.506499e-07        5.000000
# 69364                         5              5.506499e-07        5.000000
# 84938                         5              5.506499e-07        5.050505
# 84939                         5              5.506499e-07        5.050505
# 64880                         5              5.506499e-07        5.050505
#
#               lift
# 69325  1097.037453
# 84902  6834.396357
# 69327  3149.559140
# 69329  3755.243590
# 69360  2536.362849
# 69361  3266.251439
# 69364  3067.628041
# 84938   426.599906
# 84939  3886.397449
# 64880   227.027178

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 3 # minimum length
zmax = 3 # maximum length 
report = "asCl"
algo = "ap" # 'fp' or 'ap'

if algo == "ap":
    result = arules(apriori_array, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(apriori_array, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (97578, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(10))
# Out:
#                                          consequent  \
# 10             Black Solid Jade HW Skinny Denim TRS
# 12        Light Blue Solid Jade HW Skinny Denim TRS
# 11         Dark Blue Solid Jade HW Skinny Denim TRS
# 309        Dark Blue Solid Jade HW Skinny Denim TRS
# 310        Dark Grey Solid Jade HW Skinny Denim TRS
# 308            Black Solid Jade HW Skinny Denim TRS
# 5504        Dark Green Solid The Low Line Highwaist
# 5503  Beige All over pattern The Low Line Highwaist
# 5502           Dark Green Solid Timeless Sports Top
# 5456        Dark Green Solid The Low Line Highwaist
#
#                                                                                     antecedent  \
# 10       (Light Blue Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 12            (Dark Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 11           (Light Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 309           (Dark Grey Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 310           (Dark Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 308       (Dark Grey Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 5504     (Beige All over pattern The Low Line Highwaist, Dark Green Solid Timeless Sports Top)
# 5503           (Dark Green Solid The Low Line Highwaist, Dark Green Solid Timeless Sports Top)
# 5502  (Dark Green Solid The Low Line Highwaist, Beige All over pattern The Low Line Highwaist)
# 5456        (Dark Green Solid Timeless Sports Top, Beige All over pattern Timeless Sports Top)
#
#       support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 10                        1369                  0.000151       22.992946
# 12                        1369                  0.000151       19.214035
# 11                        1369                  0.000151       24.161666
# 309                        818                  0.000090       29.659173
# 310                        818                  0.000090       11.480702
# 308                        818                  0.000090       25.902470
# 5504                       705                  0.000078       90.384615
# 5503                       705                  0.000078       15.286210
# 5502                       705                  0.000078       81.221198
# 5456                       694                  0.000076       71.768356
#
#              lift
# 10      48.190394
# 12      53.576612
# 11      57.091770
# 309     70.081868
# 310     71.859673
# 308     54.288400
# 5504  1367.163896
# 5503   201.570610
# 5502  1079.641367
# 5456  1085.573075

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(10))
# Out:
#                                          consequent  \
# 35613    Black Solid Chubba Chubb Highwaist brazili
# 66147        Yellowish Brown Solid 20 den 2p Tights
# 87794                 Dark Blue Melange Calista (1)
# 66144              Black Solid Lyra HW wide full(1)
# 87800           Light Pink Solid Barry cardigan (1)
# 66123                Light Beige Melange Son V-neck
# 66121      Black Solid Harrison short sleeve top CN
# 66116                        Light Beige Neps Flock
# 66115                        Black Solid Son V-neck
# 97577  Dark Turquoise All over pattern 1 pk Sneaker
#
#                                                                      antecedent  \
# 35613     (White Solid Knot Bitter Top, Black All over pattern Knot Bitter Top)
# 66147  (Black Solid Control Top 50 den 1p Tights, Black Solid 20 den 2p Tights)
# 87794              (Light Pink Melange Calista., Black Solid Calista cardigan.)
# 66144                       (Black Solid Jennifer trouser, Black Solid Drizzle)
# 87800              (Light Pink Melange Calista., Black Solid Calista cardigan.)
# 66123                         (Light Beige Neps Flock, Dark Blue Melange Flock)
# 66121                         (Light Beige Neps Flock, Dark Blue Melange Flock)
# 66116                       (Black Solid Son V-neck, Dark Blue Solid Flock (1))
# 66115                       (Light Beige Neps Flock, Dark Blue Solid Flock (1))
# 97577    (Dark Green All over pattern 1pk Smart, Blue All over pattern 1pk Fun)
#
#        support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 35613                         5              5.506499e-07        5.050505
# 66147                         5              5.506499e-07        5.208333
# 87794                         5              5.506499e-07        5.434783
# 66144                         5              5.506499e-07        5.208333
# 87800                         5              5.506499e-07        5.434783
# 66123                         5              5.506499e-07        5.000000
# 66121                         5              5.506499e-07        5.000000
# 66116                         5              5.506499e-07        5.434783
# 66115                         5              5.506499e-07        5.263158
# 97577                         5              5.506499e-07        5.434783
#
#                lift
# 35613    113.401310
# 66147    260.278475
# 87794    189.075858
# 66144    380.777769
# 87800    386.746073
# 66123     92.711650
# 66121     39.081428
# 66116    367.451965
# 66115     86.954905
# 97577  16449.599638

# %% [markdown]
# Analysis by product type granularity

# %%
prod_type_df=transactions_merged2.groupby(["t_dat", "customer_id"],as_index=False)["product_type_name"].agg(','.join)
prod_type_df["product_type_name"]= prod_type_df["product_type_name"].str.split(",", n = 100, expand = False)

# %%
len(prod_type_df)
# Out:
# 9080179

# %%
apriori_array = prod_type_df["product_type_name"].to_numpy()

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 2 # minimum length
zmax = 2 # maximum length 
report = "asCl"
algo = "ap" # 'fp' or 'ap'


# run apriori
if algo == "ap":
    result = arules(apriori_array, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(apriori_array, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (1840, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#            consequent           antecedent  support_itemset_absolute  \
# 2            Trousers           (Sweater,)                    498339
# 3             Sweater          (Trousers,)                    498339
# 146   Swimwear bottom        (Bikini top,)                    463018
# 147        Bikini top   (Swimwear bottom,)                    463018
# 1               Dress          (Trousers,)                    385073
# 0            Trousers             (Dress,)                    385073
# 6            Trousers           (T-shirt,)                    366951
# 7             T-shirt          (Trousers,)                    366951
# 12           Trousers               (Top,)                    339933
# 13                Top          (Trousers,)                    339933
# 21             Blouse          (Trousers,)                    312628
# 20           Trousers            (Blouse,)                    312628
# 16            Sweater               (Top,)                    272174
# 17                Top           (Sweater,)                    272174
# 103  Underwear bottom               (Bra,)                    262678
# 102               Bra  (Underwear bottom,)                    262678
# 18            T-shirt               (Top,)                    260327
# 19                Top           (T-shirt,)                    260327
# 11            T-shirt           (Sweater,)                    255592
# 10            Sweater           (T-shirt,)                    255592
#
#      support_itemset_relative  confidence_pct       lift
# 2                    0.054882       29.472831   1.163248
# 3                    0.054882       21.661130   1.163248
# 146                  0.050992       78.190971  12.109265
# 147                  0.050992       78.970456  12.109265
# 1                    0.042408       16.737836   0.867179
# 0                    0.042408       21.971428   0.867179
# 6                    0.040412       29.211960   1.152952
# 7                    0.040412       15.950133   1.152952
# 12                   0.037437       30.821743   1.216488
# 13                   0.037437       14.775751   1.216488
# 21                   0.034430       13.588894   1.251333
# 20                   0.034430       31.704604   1.251333
# 16                   0.029975       24.678031   1.325262
# 17                   0.029975       16.096951   1.325262
# 103                  0.028929       32.586037   4.686585
# 102                  0.028929       41.605831   4.686585
# 18                   0.028670       23.603863   1.706201
# 19                   0.028670       20.723916   1.706201
# 11                   0.028148       15.116256   1.092676
# 10                   0.028148       20.346976   1.092676

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#             consequent     antecedent  support_itemset_absolute  \
# 1831            Shorts    (Keychain,)                         8
# 1778            Blazer  (Sewing kit,)                         8
# 1835            Hoodie    (Keychain,)                         8
# 1800           Sandals  (Marker pen,)                         8
# 1809  Underwear bottom    (Dog wear,)                         8
# 1815             Dress    (Headband,)                         8
# 1753            Blouse    (Baby Bib,)                         8
# 1759            Hoodie    (Baby Bib,)                         8
# 1830          Vest top    (Keychain,)                         7
# 1837              Belt    (Keychain,)                         7
# 1799   Leggings/Tights  (Marker pen,)                         7
# 1776   Leggings/Tights  (Sewing kit,)                         7
# 1791            Blouse  (Marker pen,)                         7
# 1781              Belt  (Sewing kit,)                         7
# 1785   Hair/alice band  (Sewing kit,)                         6
# 1832  Underwear bottom    (Keychain,)                         6
# 1834            Jacket    (Keychain,)                         6
# 1782           Earring  (Sewing kit,)                         6
# 1783             Scarf  (Sewing kit,)                         6
# 1784        Sunglasses  (Sewing kit,)                         6
#
#       support_itemset_relative  confidence_pct      lift
# 1831              8.810399e-07        6.666667  0.967580
# 1778              8.810399e-07        7.619048  1.984547
# 1835              8.810399e-07        6.666667  1.646651
# 1800              8.810399e-07        6.299213  6.070297
# 1809              8.810399e-07        5.063291  0.728212
# 1815              8.810399e-07        5.228758  0.270899
# 1753              8.810399e-07        5.333333  0.491120
# 1759              8.810399e-07        5.333333  1.317321
# 1830              7.709099e-07        5.833333  0.637069
# 1837              7.709099e-07        5.833333  3.166051
# 1799              7.709099e-07        5.511811  0.978793
# 1776              7.709099e-07        6.666667  1.183873
# 1791              7.709099e-07        5.511811  0.507555
# 1781              7.709099e-07        6.666667  3.618344
# 1785              6.607799e-07        5.714286  6.987925
# 1832              6.607799e-07        5.000000  0.719109
# 1834              6.607799e-07        5.000000  0.964421
# 1782              6.607799e-07        5.714286  3.568012
# 1783              6.607799e-07        5.714286  3.902520
# 1784              6.607799e-07        5.714286  5.640721

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 3 # minimum length
zmax = 3 # maximum length 
report = "asCl"
algo = "ap" # 'fp' or 'ap'


# run apriori
if algo == "ap":
    result = arules(apriori_array, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(apriori_array, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (66018, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#    consequent           antecedent  support_itemset_absolute  \
# 17        Top  (Sweater, Trousers)                    110141
# 16    Sweater      (Top, Trousers)                    110141
# 15   Trousers       (Top, Sweater)                    110141
# 6    Trousers   (T-shirt, Sweater)                    103697
# 7     Sweater  (T-shirt, Trousers)                    103697
# 8     T-shirt  (Sweater, Trousers)                    103697
# 23        Top  (T-shirt, Trousers)                     99154
# 22    T-shirt      (Top, Trousers)                     99154
# 21   Trousers       (Top, T-shirt)                     99154
# 13      Dress      (Top, Trousers)                     96422
# 12   Trousers         (Top, Dress)                     96422
# 14        Top    (Dress, Trousers)                     96422
# 0    Trousers     (Sweater, Dress)                     96220
# 1       Dress  (Sweater, Trousers)                     96220
# 2     Sweater    (Dress, Trousers)                     96220
# 30   Trousers      (Blouse, Dress)                     95294
# 32     Blouse    (Dress, Trousers)                     95294
# 31      Dress   (Blouse, Trousers)                     95294
# 5     T-shirt    (Dress, Trousers)                     89407
# 4       Dress  (T-shirt, Trousers)                     89407
#
#     support_itemset_relative  confidence_pct      lift
# 17                  0.012130       22.101622  1.819627
# 16                  0.012130       32.400797  1.739991
# 15                  0.012130       40.467128  1.597177
# 6                   0.011420       40.571301  1.601289
# 7                   0.011420       28.259086  1.517573
# 8                   0.011420       20.808526  1.504140
# 23                  0.010920       27.021046  2.224644
# 22                  0.010920       29.168689  2.108453
# 21                  0.010920       38.088251  1.503286
# 13                  0.010619       28.365001  1.469577
# 12                  0.010619       38.364089  1.514173
# 14                  0.010619       25.039927  2.061538
# 0                   0.010597       40.216001  1.587265
# 1                   0.010597       19.308142  1.000346
# 2                   0.010597       24.987470  1.341880
# 30                  0.010495       38.173792  1.506662
# 32                  0.010495       24.746996  2.278827
# 31                  0.010495       30.481595  1.579237
# 5                   0.009846       23.218195  1.678323
# 4                   0.009846       24.364833  1.262330

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#               consequent                       antecedent  \
# 62605           Cardigan      (Backpack, Leggings/Tights)
# 51620      Pyjama bottom  (Underdress, Other accessories)
# 38566            Earring               (Other shoe, Robe)
# 38564               Belt               (Other shoe, Robe)
# 41785         Ballerinas            (Slippers, Hair clip)
# 25114            Sandals          (Hair ties, Ballerinas)
# 41784      Pyjama bottom            (Slippers, Hair clip)
# 50770         Pyjama set        (Costumes, Pyjama bottom)
# 43316           Necklace           (Flip flop, Hair ties)
# 52218         Sunglasses   (Kids Underwear top, Swimsuit)
# 60628           Sneakers                  (Bootie, Shirt)
# 65754   Underwear bottom        (Cross-body bag, Sweater)
# 50767              Socks        (Costumes, Pyjama bottom)
# 50715  Jumpsuit/Playsuit           (Costumes, Sunglasses)
# 65749             Shorts        (Cross-body bag, Sweater)
# 62261             Blazer     (Dog Wear, Underwear bottom)
# 43315               Belt           (Flip flop, Hair ties)
# 57284         Hat/beanie                  (Tie, Cardigan)
# 51536              Boots         (Underdress, Sunglasses)
# 61271           Necklace             (Tote bag, Cardigan)
#
#        support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 62605                         5              5.506499e-07        5.319149
# 51620                         5              5.506499e-07        5.000000
# 38566                         5              5.506499e-07        5.494505
# 38564                         5              5.506499e-07        5.494505
# 41785                         5              5.506499e-07        5.208333
# 25114                         5              5.506499e-07        5.319149
# 41784                         5              5.506499e-07        5.208333
# 50770                         5              5.506499e-07        5.376344
# 43316                         5              5.506499e-07        5.154639
# 52218                         5              5.506499e-07        5.154639
# 60628                         5              5.506499e-07        5.376344
# 65754                         5              5.506499e-07        5.434783
# 50767                         5              5.506499e-07        5.376344
# 50715                         5              5.506499e-07        5.102041
# 65749                         5              5.506499e-07        5.434783
# 62261                         5              5.506499e-07        5.102041
# 43315                         5              5.506499e-07        5.154639
# 57284                         5              5.506499e-07        5.263158
# 51536                         5              5.506499e-07        5.102041
# 61271                         5              5.506499e-07        5.154639
#
#             lift
# 62605   1.691017
# 51620   6.017747
# 38566   3.430780
# 38564   2.982151
# 41785  12.499696
# 25114   5.125849
# 41784   6.268487
# 50770   3.308069
# 43316   4.220701
# 52218   5.088279
# 60628   5.066490
# 65754   0.781641
# 50767   1.481952
# 50715   2.760363
# 65749   0.788788
# 62261   1.328938
# 43315   2.797688
# 57284   6.629547
# 51536   3.123985
# 61271   4.220701

# %% [markdown]
# ## Analysis on age segment 19-26

# %%
article_name_age = pd.merge(article_name_df, customers[["customer_id", "age"]], on="customer_id")
prod_type_age = pd.merge(prod_type_df, customers[["customer_id", "age"]], on="customer_id")

# %%
article_name_young = article_name_age[ (article_name_age["age"] > 18) &
                     (article_name_age["age"] < 27) ]
prod_type_young = prod_type_age[ (prod_type_age["age"] > 18) &
                     (prod_type_age["age"] < 27) ]

# %%
array_young = article_name_young["article_name"].to_numpy()
array_type_young = prod_type_young["product_type_name"].to_numpy()

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 2 # minimum length
zmax = 2 # maximum length 
report = "asCl"
algo = 'ap' # 'fp' or 'ap'
# run apriori
if algo == "ap":
    result = arules(array_young, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(array_young, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (108996, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#                                                      consequent  \
# 0                          Black Solid Jade HW Skinny Denim TRS
# 1                      Dark Blue Solid Jade HW Skinny Denim TRS
# 6                                        Black Solid Tilda tank
# 7                                        White Solid Tilda tank
# 41       Dark Green Other structure Simple as That Triangle Top
# 40       Dark Green Other structure Simple as that Cheeky Tanga
# 49              Red Other structure Simple as That Triangle Top
# 50              Red Other structure Simple as that Cheeky Tanga
# 3                     Light Blue Solid Jade HW Skinny Denim TRS
# 2                          Black Solid Jade HW Skinny Denim TRS
# 5                     Light Blue Solid Jade HW Skinny Denim TRS
# 4                      Dark Blue Solid Jade HW Skinny Denim TRS
# 119                        Dark Green Solid Timeless Sports Top
# 120                     Dark Green Solid The Low Line Highwaist
# 142               Beige All over pattern The Low Line Highwaist
# 141                  Beige All over pattern Timeless Sports Top
# 19            Black Other structure Simple as that Cheeky Tanga
# 20            Black Other structure Simple as That Triangle Top
# 530     Greenish Khaki All over pattern LS Reggipetto Tie Tanga
# 529  Greenish Khaki All over pattern LS Reggipetto Triangle Top
#
#                                                         antecedent  \
# 0                      (Dark Blue Solid Jade HW Skinny Denim TRS,)
# 1                          (Black Solid Jade HW Skinny Denim TRS,)
# 6                                        (White Solid Tilda tank,)
# 7                                        (Black Solid Tilda tank,)
# 41       (Dark Green Other structure Simple as that Cheeky Tanga,)
# 40       (Dark Green Other structure Simple as That Triangle Top,)
# 49              (Red Other structure Simple as that Cheeky Tanga,)
# 50              (Red Other structure Simple as That Triangle Top,)
# 3                          (Black Solid Jade HW Skinny Denim TRS,)
# 2                     (Light Blue Solid Jade HW Skinny Denim TRS,)
# 5                      (Dark Blue Solid Jade HW Skinny Denim TRS,)
# 4                     (Light Blue Solid Jade HW Skinny Denim TRS,)
# 119                     (Dark Green Solid The Low Line Highwaist,)
# 120                        (Dark Green Solid Timeless Sports Top,)
# 142                  (Beige All over pattern Timeless Sports Top,)
# 141               (Beige All over pattern The Low Line Highwaist,)
# 19            (Black Other structure Simple as That Triangle Top,)
# 20            (Black Other structure Simple as that Cheeky Tanga,)
# 530  (Greenish Khaki All over pattern LS Reggipetto Triangle Top,)
# 529     (Greenish Khaki All over pattern LS Reggipetto Tie Tanga,)
#
#      support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 0                        3081                  0.001072       19.518530
# 1                        3081                  0.001072       15.628487
# 6                        3066                  0.001067       35.428703
# 7                        3066                  0.001067       23.370684
# 41                       2980                  0.001037       66.340160
# 40                       2980                  0.001037       70.134149
# 49                       2794                  0.000972       66.161497
# 50                       2794                  0.000972       48.114345
# 3                        2617                  0.000911       13.274830
# 2                        2617                  0.000911       18.145888
# 5                        2484                  0.000864       15.736459
# 4                        2484                  0.000864       17.223686
# 119                      2170                  0.000755       78.226388
# 120                      2170                  0.000755       69.042316
# 142                      2012                  0.000700       59.228731
# 141                      2012                  0.000700       67.584817
# 19                       1702                  0.000592       32.882535
# 20                       1702                  0.000592       28.667677
# 530                      1666                  0.000580       74.608150
# 529                      1666                  0.000580       81.947860
#
#             lift
# 0      28.450174
# 1      28.450174
# 6      77.600959
# 7      77.600959
# 41    448.644499
# 40    448.644499
# 49    327.390487
# 50    327.390487
# 3      26.449413
# 2      26.449413
# 5      31.354081
# 4      31.354081
# 119   715.190040
# 120   715.190040
# 142   571.697320
# 141   571.697320
# 19    159.151524
# 20    159.151524
# 530  1054.536113
# 529  1054.536113

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#                                           consequent  \
# 83239         Black Other structure FF Begonia shirt
# 83240                Gold Solid Flirty Tara necklace
# 83226     Dark Green Melange CONAN STRUCTURE SWEATER
# 83225           Beige Melange MUSHROOM SLIM FIT POLO
# 59838                           Beige Solid Bird tee
# 59839               White Solid ESSENTIAL LOVA LINEN
# 83222   Dark Blue Check Jamie Skinny Cropped Trs Pid
# 83221      Light Blue Melange MUSHROOM SLIM FIT POLO
# 83220                          Black Neps PETER POLO
# 83219                Black All over pattern BORIS SS
# 83217                 Greenish Khaki Melange Taz Tee
# 83216         Dark Blue All over pattern FORTUNA TEE
# 83215                     Black Solid ZOLA MID SKIRT
# 83214                        Black Solid Smirk Dress
# 83213                    Black Lace Swing lace dress
# 83212                      Black Solid Gin and Juice
# 83211             Black All over pattern AVRIL DRESS
# 83210             Black Solid Bee Waterfall Cardigan
# 83209                  White Solid Maja Cardigan TVP
# 108995          Black Glittering/Metallic Frida Pile
#
#                                                     antecedent  \
# 83239                         (Gold Solid Cool Dylan hoop pk,)
# 83240                         (Gold Solid Cool Dylan hoop pk,)
# 83226   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83225   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 59838                  (Dark Grey Solid Linnea linen t-shirt,)
# 59839                  (Dark Grey Solid Linnea linen t-shirt,)
# 83222   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83221   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83220   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83219   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83217   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83216   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83215   (Dark Blue Other structure PORTOBELLO SS MUSCLE POLO,)
# 83214                            (Black Solid Fredrika Dress,)
# 83213                            (Black Solid Fredrika Dress,)
# 83212                            (Black Solid Fredrika Dress,)
# 83211                            (Black Solid Fredrika Dress,)
# 83210             (Light Orange Solid Bee Waterfall Cardigan,)
# 83209             (Light Orange Solid Bee Waterfall Cardigan,)
# 108995                             (Black Solid Agnes blouse,)
#
#         support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 83239                          2              6.960131e-07        5.000000
# 83240                          2              6.960131e-07        5.000000
# 83226                          2              6.960131e-07        6.666667
# 83225                          2              6.960131e-07        6.666667
# 59838                          2              6.960131e-07        5.405405
# 59839                          2              6.960131e-07        5.405405
# 83222                          2              6.960131e-07        6.666667
# 83221                          2              6.960131e-07        6.666667
# 83220                          2              6.960131e-07        6.666667
# 83219                          2              6.960131e-07        6.666667
# 83217                          2              6.960131e-07        6.666667
# 83216                          2              6.960131e-07        6.666667
# 83215                          2              6.960131e-07        6.666667
# 83214                          2              6.960131e-07        6.896552
# 83213                          2              6.960131e-07        6.896552
# 83212                          2              6.960131e-07        6.896552
# 83211                          2              6.960131e-07        6.896552
# 83210                          2              6.960131e-07        5.555556
# 83209                          2              6.960131e-07        5.555556
# 108995                         2              6.960131e-07        6.250000
#
#                 lift
# 83239     316.465749
# 83240     440.722239
# 83226    2016.497544
# 83225    1651.441954
# 59838     283.957607
# 59839     400.321677
# 83222     843.908664
# 83221     982.396239
# 83220     899.376839
# 83219     676.916137
# 83217     368.398590
# 83216     386.224328
# 83215     169.678713
# 83214    2642.307126
# 83213    2331.447465
# 83212    1738.359952
# 83211     187.841739
# 83210    2533.958554
# 83209     431.457808
# 108995  89797.156250

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 3 # minimum length
zmax = 3 # maximum length 
report = "asCl"
algo = 'ap' # 'fp' or 'ap'
# run apriori
if algo == "ap":
    result = arules(array_young, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(array_young, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (176784, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#                                                        consequent  \
# 0                            Black Solid Jade HW Skinny Denim TRS
# 2                       Light Blue Solid Jade HW Skinny Denim TRS
# 1                        Dark Blue Solid Jade HW Skinny Denim TRS
# 4365                                      Grey Melange Tilda tank
# 4363                                       Black Solid Tilda tank
# 4364                                       White Solid Tilda tank
# 62399                     Off White Front print LS Birdie T-Shirt
# 62397  Greenish Khaki All over pattern LS Reggipetto Triangle Top
# 62398     Greenish Khaki All over pattern LS Reggipetto Tie Tanga
# 420                      Dark Grey Solid Jade HW Skinny Denim TRS
# 419                      Dark Blue Solid Jade HW Skinny Denim TRS
# 418                          Black Solid Jade HW Skinny Denim TRS
# 4466                         Dark Green Solid Timeless Sports Top
# 4467                      Dark Green Solid The Low Line Highwaist
# 4468                Beige All over pattern The Low Line Highwaist
# 3764                         Dark Green Solid Timeless Sports Top
# 3765                   Beige All over pattern Timeless Sports Top
# 3766                      Dark Green Solid The Low Line Highwaist
# 1263                                      Beige Solid Therese tee
# 1264                                      White Solid Therese tee
#
#                                                                                                                   antecedent  \
# 0                                      (Light Blue Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 2                                           (Dark Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 1                                          (Light Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 4365                                                                        (White Solid Tilda tank, Black Solid Tilda tank)
# 4363                                                                       (Grey Melange Tilda tank, White Solid Tilda tank)
# 4364                                                                       (Grey Melange Tilda tank, Black Solid Tilda tank)
# 62399  (Greenish Khaki All over pattern LS Reggipetto Tie Tanga, Greenish Khaki All over pattern LS Reggipetto Triangle Top)
# 62397                     (Off White Front print LS Birdie T-Shirt, Greenish Khaki All over pattern LS Reggipetto Tie Tanga)
# 62398                  (Off White Front print LS Birdie T-Shirt, Greenish Khaki All over pattern LS Reggipetto Triangle Top)
# 420                                         (Dark Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 419                                         (Dark Grey Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 418                                     (Dark Grey Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 4466                                (Beige All over pattern The Low Line Highwaist, Dark Green Solid The Low Line Highwaist)
# 4467                                   (Beige All over pattern The Low Line Highwaist, Dark Green Solid Timeless Sports Top)
# 4468                                         (Dark Green Solid The Low Line Highwaist, Dark Green Solid Timeless Sports Top)
# 3764                                   (Dark Green Solid The Low Line Highwaist, Beige All over pattern Timeless Sports Top)
# 3765                                         (Dark Green Solid The Low Line Highwaist, Dark Green Solid Timeless Sports Top)
# 3766                                      (Beige All over pattern Timeless Sports Top, Dark Green Solid Timeless Sports Top)
# 1263                                                                      (Black Solid Therese tee, White Solid Therese tee)
# 1264                                                                      (Black Solid Therese tee, Beige Solid Therese tee)
#
#        support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 0                           609                  0.000212       24.516908
# 2                           609                  0.000212       19.766310
# 1                           609                  0.000212       23.270921
# 4365                        367                  0.000128       11.969993
# 4363                        367                  0.000128       47.600519
# 4364                        367                  0.000128       40.374037
# 62399                       346                  0.000120       20.768307
# 62397                       346                  0.000120       91.777188
# 62398                       346                  0.000120       84.596577
# 420                         317                  0.000110       10.288867
# 419                         317                  0.000110       29.029304
# 418                         317                  0.000110       26.549414
# 4466                        310                  0.000108       81.364829
# 4467                        310                  0.000108       91.715976
# 4468                        310                  0.000108       14.285714
# 3764                        301                  0.000105       94.062500
# 3765                        301                  0.000105       13.870968
# 3766                        301                  0.000105       76.982097
# 1263                        299                  0.000104       24.508197
# 1264                        299                  0.000104       36.507937
#
#               lift
# 0        35.735800
# 2        39.383351
# 1        42.362496
# 4365    125.532423
# 4363    104.261391
# 4364    134.059579
# 62399   490.369088
# 62397  1181.023630
# 62398  1195.715816
# 420      53.203442
# 419      52.845085
# 418      38.698376
# 4466    743.883454
# 4467    950.060142
# 4468    137.890926
# 3764    859.972766
# 3765    117.333973
# 3766    797.436010
# 1263    108.931978
# 1264    223.679924

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#                                                consequent  \
# 104994                      Black Solid Twenty HW tapered
# 104995                                   White Solid Mona
# 105026                      Dark Pink Solid Queen Sweater
# 105023                               Yellow Melange SIRPA
# 105022                Off White Solid Tara turtleneck top
# 105021                                 Black Solid Techno
# 105020                             Black Solid Jodi skirt
# 105019                            Black Solid JESSY SKIRT
# 105016                     Dark Blue Solid Jade Denim TRS
# 105015                    Light Blue Solid Jade Denim TRS
# 105014                Black Denim Straight HW ankle Femme
# 105013            Black Solid Mimosa Push Melbourne Opt.2
# 105008                       Dark Blue Solid Primo slacks
# 105007                           Black Check Primo slacks
# 105005                      Black Solid Twenty HW tapered
# 105002               Blue Solid Perrie Slim Mom Denim TRS
# 104998                    Black All over pattern Enter(1)
# 104997                         Black Solid ZOLA MID SKIRT
# 104996  Dark Green All over pattern Timeless Triangle Top
# 176783          Dark Yellow Solid KIDS-Mikonos Bucket Hat
#
#                                                                          antecedent  \
# 104994  (Black Dot Pluto RW slacks (1), Black All over pattern Pluto RW slacks (1))
# 104995  (Black Dot Pluto RW slacks (1), Black All over pattern Pluto RW slacks (1))
# 105026                                  (Red Melange SIRPA, Dark Red Melange SIRPA)
# 105023                                       (Red Melange SIRPA, Black Solid SIRPA)
# 105022                                       (Red Melange SIRPA, Black Solid SIRPA)
# 105021                                       (Red Melange SIRPA, Black Solid SIRPA)
# 105020                                  (Red Melange SIRPA, Dark Red Melange SIRPA)
# 105019                                  (Red Melange SIRPA, Dark Red Melange SIRPA)
# 105016                                  (Red Melange SIRPA, Dark Red Melange SIRPA)
# 105015                                       (Red Melange SIRPA, Black Solid SIRPA)
# 105014         (Black Dot Pluto RW slacks (1), Black All over pattern Primo slacks)
# 105013  (Black Dot Pluto RW slacks (1), Black All over pattern Pluto RW slacks (1))
# 105008         (Black Dot Pluto RW slacks (1), Black All over pattern Primo slacks)
# 105007         (Black Dot Pluto RW slacks (1), Black All over pattern Primo slacks)
# 105005         (Black Dot Pluto RW slacks (1), Black All over pattern Primo slacks)
# 105002         (Black Dot Pluto RW slacks (1), Black All over pattern Primo slacks)
# 104998  (Black Dot Pluto RW slacks (1), Black All over pattern Pluto RW slacks (1))
# 104997  (Black Dot Pluto RW slacks (1), Black All over pattern Pluto RW slacks (1))
# 104996  (Black Dot Pluto RW slacks (1), Black All over pattern Pluto RW slacks (1))
# 176783       (Light Red Solid Venice wide side thong, Light Red Solid Lash wirebra)
#
#         support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 104994                         2              6.960131e-07        5.714286
# 104995                         2              6.960131e-07        5.714286
# 105026                         2              6.960131e-07        6.250000
# 105023                         2              6.960131e-07        6.666667
# 105022                         2              6.960131e-07        6.666667
# 105021                         2              6.960131e-07        6.666667
# 105020                         2              6.960131e-07        6.250000
# 105019                         2              6.960131e-07        6.250000
# 105016                         2              6.960131e-07        6.250000
# 105015                         2              6.960131e-07        6.666667
# 105014                         2              6.960131e-07        5.128205
# 105013                         2              6.960131e-07        5.714286
# 105008                         2              6.960131e-07        5.128205
# 105007                         2              6.960131e-07        5.128205
# 105005                         2              6.960131e-07        5.128205
# 105002                         2              6.960131e-07        5.128205
# 104998                         2              6.960131e-07        5.714286
# 104997                         2              6.960131e-07        5.714286
# 104996                         2              6.960131e-07        5.714286
# 176783                         2              6.960131e-07        6.666667
#
#                 lift
# 104994     56.699073
# 104995     83.223778
# 105026    278.873156
# 105023    189.670561
# 105022    204.011999
# 105021    166.725210
# 105020    152.327661
# 105019    117.535545
# 105016     53.578256
# 105015     43.165225
# 105014    206.965500
# 105013    226.171507
# 105008     97.718459
# 105007    104.067398
# 105005     50.883783
# 105002     16.904834
# 104998    142.288141
# 104997    145.438897
# 104996     82.637400
# 176783  95783.633333

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 2 # minimum length
zmax = 2 # maximum length 
report = "asCl"
algo = "ap" # 'fp' or 'ap'
# run apriori
if algo == "ap":
    result = arules(array_type_young, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(array_type_young, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (1644, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#            consequent           antecedent  support_itemset_absolute  \
# 85    Swimwear bottom        (Bikini top,)                    186234
# 84         Bikini top   (Swimwear bottom,)                    186234
# 2            Trousers           (Sweater,)                    135896
# 3             Sweater          (Trousers,)                    135896
# 6            Trousers           (T-shirt,)                    100136
# 7             T-shirt          (Trousers,)                    100136
# 0            Trousers             (Dress,)                     98516
# 1               Dress          (Trousers,)                     98516
# 140               Bra  (Underwear bottom,)                     96948
# 141  Underwear bottom               (Bra,)                     96948
# 13                Top          (Trousers,)                     92653
# 12           Trousers               (Top,)                     92653
# 30           Trousers            (Blouse,)                     81963
# 31             Blouse          (Trousers,)                     81963
# 16            Sweater               (Top,)                     79249
# 17                Top           (Sweater,)                     79249
# 18            T-shirt               (Top,)                     74240
# 19                Top           (T-shirt,)                     74240
# 10            Sweater           (T-shirt,)                     72376
# 11            T-shirt           (Sweater,)                     72376
#
#      support_itemset_relative  confidence_pct      lift
# 85                   0.064811       77.632111  9.645595
# 84                   0.064811       80.525613  9.645595
# 2                    0.047293       26.652180  1.191212
# 3                    0.047293       21.137344  1.191212
# 6                    0.034848       25.914711  1.158251
# 7                    0.034848       15.575212  1.158251
# 0                    0.034284       20.086531  0.897762
# 1                    0.034284       15.323237  0.897762
# 140                  0.033739       44.994152  4.342168
# 141                  0.033739       32.559436  4.342168
# 13                   0.032244       14.411302  1.254176
# 12                   0.032244       28.060936  1.254176
# 30                   0.028524       29.775818  1.330822
# 31                   0.028524       12.748573  1.330822
# 16                   0.027579       24.001393  1.352618
# 17                   0.027579       15.542463  1.352618
# 18                   0.025836       22.484365  1.672050
# 19                   0.025836       19.212952  1.672050
# 10                   0.025187       18.730558  1.055576
# 11                   0.025187       14.194518  1.055576

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#              consequent        antecedent  support_itemset_absolute  \
# 1576                Bag     (Sewing kit,)                         4
# 1577               Belt     (Sewing kit,)                         3
# 1639                Top       (Dog wear,)                         3
# 1640             Blouse       (Dog wear,)                         3
# 1641    Leggings/Tights       (Dog wear,)                         3
# 1574             Blazer     (Sewing kit,)                         3
# 1635           Bracelet       (Keychain,)                         3
# 1575              Socks     (Sewing kit,)                         3
# 1609           Slippers  (Sleeping sack,)                         3
# 1578            Earring     (Sewing kit,)                         3
# 1580  Other accessories     (Sewing kit,)                         3
# 1614            Sweater     (Marker pen,)                         3
# 1626              Dress       (Keychain,)                         3
# 1624           Bodysuit     (Marker pen,)                         3
# 1601             Hoodie  (Sleeping sack,)                         3
# 1619         Bikini top     (Marker pen,)                         3
# 1604           Swimsuit  (Sleeping sack,)                         3
# 1606         Pyjama set  (Sleeping sack,)                         3
# 1608          Dungarees  (Sleeping sack,)                         3
# 1643             Blazer       (Dog wear,)                         3
#
#       support_itemset_relative  confidence_pct       lift
# 1576                  0.000001        7.547170   3.196530
# 1577                  0.000001        5.660377   2.486341
# 1639                  0.000001        6.666667   0.580182
# 1640                  0.000001        6.666667   0.695933
# 1641                  0.000001        6.666667   1.340888
# 1574                  0.000001        5.660377   1.472985
# 1635                  0.000001        6.521739  62.260053
# 1575                  0.000001        5.660377   1.754865
# 1609                  0.000001        6.818182  40.672840
# 1578                  0.000001        5.660377   2.916259
# 1580                  0.000001        5.660377   6.133624
# 1614                  0.000001        5.660377   0.318995
# 1626                  0.000001        6.521739   0.382097
# 1624                  0.000001        5.660377   4.544479
# 1601                  0.000001        6.818182   1.591858
# 1619                  0.000001        5.660377   0.678017
# 1604                  0.000001        6.818182   3.170552
# 1606                  0.000001        6.818182   5.058769
# 1608                  0.000001        6.818182  24.113362
# 1643                  0.000001        6.666667   1.734849

# %% [markdown]
# ## Analysis on age segment 46-54

# %%
article_name_old = article_name_age[ (article_name_age['age'] > 46) &
                     (article_name_age["age"] < 54) ]
prod_type_old = prod_type_age[ (prod_type_age['age'] > 46) &
                     (prod_type_age["age"] < 54) ]

# %%
array_old = article_name_old["article_name"].to_numpy()
array_type_old = prod_type_old["product_type_name"].to_numpy()

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 2 # minimum length
zmax = 2 # maximum length 
report = "asCl"
algo = 'ap' # 'fp' or 'ap'
# run apriori
if algo == "ap":
    result = arules(array_old, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == "fp":
    result = fpgrowth(array_old, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == "ap":
    colnames = ["consequent", "antecedent"] + [report_colnames.get(k, k) for k in list(report)]
elif algo == "fp":
    colnames = ["itemset"] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values("support_itemset_absolute", ascending=False)
print(df_result.shape)
# Out:
# (678542, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#                                                  consequent  \
# 2                      Black Solid Jade HW Skinny Denim TRS
# 3                  Dark Blue Solid Jade HW Skinny Denim TRS
# 75   Dark Green Other structure Simple as that Cheeky Tanga
# 76   Dark Green Other structure Simple as That Triangle Top
# 4                      Black Solid Jade HW Skinny Denim TRS
# 5                 Light Blue Solid Jade HW Skinny Denim TRS
# 6                  Dark Blue Solid Jade HW Skinny Denim TRS
# 7                 Light Blue Solid Jade HW Skinny Denim TRS
# 0                                Black Solid Luna skinny RW
# 1                                 Blue Denim Luna skinny RW
# 117         Red Other structure Simple as that Cheeky Tanga
# 116         Red Other structure Simple as That Triangle Top
# 108                    Black Solid Love Affair Triangle Top
# 107                 Black Solid Love Affair High Rise Brief
# 60                            Black Solid Lazer Razer Brief
# 61               Black Solid Lazer Razer Adj. push triangle
# 9                            Black Solid 7p Basic Shaftless
# 8                            White Solid 7p Basic Shaftless
# 145   Black All over pattern S Timeless High Wide Side Brie
# 144           Black All over pattern Shake it in Balconette
#
#                                                     antecedent  \
# 2                  (Dark Blue Solid Jade HW Skinny Denim TRS,)
# 3                      (Black Solid Jade HW Skinny Denim TRS,)
# 75   (Dark Green Other structure Simple as That Triangle Top,)
# 76   (Dark Green Other structure Simple as that Cheeky Tanga,)
# 4                 (Light Blue Solid Jade HW Skinny Denim TRS,)
# 5                      (Black Solid Jade HW Skinny Denim TRS,)
# 6                 (Light Blue Solid Jade HW Skinny Denim TRS,)
# 7                  (Dark Blue Solid Jade HW Skinny Denim TRS,)
# 0                                 (Blue Denim Luna skinny RW,)
# 1                                (Black Solid Luna skinny RW,)
# 117         (Red Other structure Simple as That Triangle Top,)
# 116         (Red Other structure Simple as that Cheeky Tanga,)
# 108                 (Black Solid Love Affair High Rise Brief,)
# 107                    (Black Solid Love Affair Triangle Top,)
# 60               (Black Solid Lazer Razer Adj. push triangle,)
# 61                            (Black Solid Lazer Razer Brief,)
# 9                            (White Solid 7p Basic Shaftless,)
# 8                            (Black Solid 7p Basic Shaftless,)
# 145           (Black All over pattern Shake it in Balconette,)
# 144   (Black All over pattern S Timeless High Wide Side Brie,)
#
#      support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 2                         993                  0.000745       19.129262
# 3                         993                  0.000745       17.600142
# 75                        929                  0.000697       72.352025
# 76                        929                  0.000697       64.157459
# 4                         869                  0.000652       18.187526
# 5                         869                  0.000652       15.402340
# 6                         854                  0.000641       17.873587
# 7                         854                  0.000641       16.451551
# 0                         826                  0.000620       15.688509
# 1                         826                  0.000620       14.779030
# 117                       749                  0.000562       43.170029
# 116                       749                  0.000562       64.017094
# 108                       712                  0.000534       57.142857
# 107                       712                  0.000534       61.859253
# 60                        696                  0.000522       52.807284
# 61                        696                  0.000522       26.738379
# 9                         695                  0.000521       17.340319
# 8                         695                  0.000521       16.779334
# 145                       693                  0.000520       42.857143
# 144                       693                  0.000520       63.870968
#
#            lift
# 2     45.189135
# 3     45.189135
# 75   665.964413
# 76   665.964413
# 4     42.964468
# 5     42.964468
# 6     45.891219
# 7     45.891219
# 0     37.412476
# 1     37.412476
# 117  491.773782
# 116  491.773782
# 108  661.691448
# 107  661.691448
# 60   270.388711
# 61   270.388711
# 9     55.797648
# 8     55.797648
# 145  526.456353
# 144  526.456353

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#                                               consequent  \
# 322326                    Gold Solid Flirty Lava hoop pk
# 322325                    Gold Solid Flirty Lava hoop pk
# 322322          Black Solid SPEED OL Cyckel Sheer shorts
# 322321                       Orange Solid Karin headband
# 322319                   Other Yellow Solid Kravitz body
# 322305              Black Denim Skinny H.W Ankle Festive
# 322318                            Black Stripe CLARA TEE
# 322317     Light Orange All over pattern Flirty crossbag
# 322316                             Black Solid KIMCHI LS
# 322315                               Red Solid KIMCHI LS
# 322314                 Other Yellow Solid Cycling Shorts
# 322313                    Black Stripe AK Dre polo dress
# 322312            Beige All over pattern ED Jennifer tee
# 322311                      Grey Solid Cool Vesper watch
# 322310                 Other Yellow Solid Tuti Body neon
# 322309  Light Orange All over pattern Adelia cropped top
# 322308                       Dark Blue Stripe Lotta tank
# 322307                           Black Solid DOLORES BAG
# 322306             Black All over pattern CSP Tory biker
# 678541       Dark Orange Solid PQ SUNDAY CTN/SILK KAFTAN
#
#                                            antecedent  \
# 322326  (Dark Blue All over pattern Dahlia wrap top,)
# 322325                  (Green Solid Dixie crossbag,)
# 322322                 (Orange Solid Karin headband,)
# 322321    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322319    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322305    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322318    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322317    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322316    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322315    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322314    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322313    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322312    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322311    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322310    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322309    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322308    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322307    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 322306    (Black Solid SPEED OL Cyckel Sheer shorts,)
# 678541  (Dark Blue All over pattern Sunny kaftan(1),)
#
#         support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 322326                         1              7.502934e-07        5.263158
# 322325                         1              7.502934e-07        6.666667
# 322322                         1              7.502934e-07        6.250000
# 322321                         1              7.502934e-07        5.263158
# 322319                         1              7.502934e-07        5.263158
# 322305                         1              7.502934e-07        5.263158
# 322318                         1              7.502934e-07        5.263158
# 322317                         1              7.502934e-07        5.263158
# 322316                         1              7.502934e-07        5.263158
# 322315                         1              7.502934e-07        5.263158
# 322314                         1              7.502934e-07        5.263158
# 322313                         1              7.502934e-07        5.263158
# 322312                         1              7.502934e-07        5.263158
# 322311                         1              7.502934e-07        5.263158
# 322310                         1              7.502934e-07        5.263158
# 322309                         1              7.502934e-07        5.263158
# 322308                         1              7.502934e-07        5.263158
# 322307                         1              7.502934e-07        5.263158
# 322306                         1              7.502934e-07        5.263158
# 678541                         1              7.502934e-07        6.250000
#
#                 lift
# 322326   3188.545455
# 322325   4038.824242
# 322322   4384.250000
# 322321   4384.250000
# 322319   2262.838710
# 322305   1252.642857
# 322318   2418.896552
# 322317   2004.228571
# 322316   3049.913043
# 322315   2418.896552
# 322314   2338.266667
# 322313   1895.891892
# 322312   1461.416667
# 322311   1230.666667
# 322310   2063.176471
# 322309   1670.190476
# 322308   2505.285714
# 322307   1710.926829
# 322306   1275.418182
# 678541  83300.750000

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 3 # minimum length
zmax = 3 # maximum length 
report = 'asCl'
algo = 'ap' # 'fp' or 'ap'
#  run apriori
if algo == 'ap':
    result = arules(array_old, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == 'fp':
    result = fpgrowth(array_old, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == 'ap':
    colnames = ['consequent', 'antecedent'] + [report_colnames.get(k, k) for k in list(report)]
elif algo == 'fp':
    colnames = ['itemset'] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values('support_itemset_absolute', ascending=False)
print(df_result.shape)
# Out:
# (630048, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#                                                        consequent  \
# 18                      Light Blue Solid Jade HW Skinny Denim TRS
# 17                       Dark Blue Solid Jade HW Skinny Denim TRS
# 16                           Black Solid Jade HW Skinny Denim TRS
# 530                      Dark Grey Solid Jade HW Skinny Denim TRS
# 529                      Dark Blue Solid Jade HW Skinny Denim TRS
# 528                          Black Solid Jade HW Skinny Denim TRS
# 542                      Dark Grey Solid Jade HW Skinny Denim TRS
# 540                      Dark Blue Solid Jade HW Skinny Denim TRS
# 541                     Light Blue Solid Jade HW Skinny Denim TRS
# 65247         Light Beige All over pattern LS Olivia Triangle Top
# 65248  Greenish Khaki All over pattern LS Reggipetto Triangle Top
# 65246         Light Beige All over pattern LS Olivia Cheeky Tanga
# 1618       Dark Green Other structure Simple as That Triangle Top
# 1617       Dark Green Other structure Simple as that Cheeky Tanga
# 1616            Black Other structure Simple as that Cheeky Tanga
# 535                          Black Solid Jade HW Skinny Denim TRS
# 536                     Light Blue Solid Jade HW Skinny Denim TRS
# 537                      Dark Grey Solid Jade HW Skinny Denim TRS
# 2988            Black Other structure Simple as that Cheeky Tanga
# 2989              Red Other structure Simple as That Triangle Top
#
#                                                                                                               antecedent  \
# 18                                      (Dark Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 17                                     (Light Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 16                                 (Light Blue Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 530                                     (Dark Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 529                                     (Dark Grey Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 528                                 (Dark Grey Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 542                                (Light Blue Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 540                                (Dark Grey Solid Jade HW Skinny Denim TRS, Light Blue Solid Jade HW Skinny Denim TRS)
# 541                                 (Dark Grey Solid Jade HW Skinny Denim TRS, Dark Blue Solid Jade HW Skinny Denim TRS)
# 65247  (Greenish Khaki All over pattern LS Reggipetto Triangle Top, Light Beige All over pattern LS Olivia Cheeky Tanga)
# 65248         (Light Beige All over pattern LS Olivia Triangle Top, Light Beige All over pattern LS Olivia Cheeky Tanga)
# 65246  (Greenish Khaki All over pattern LS Reggipetto Triangle Top, Light Beige All over pattern LS Olivia Triangle Top)
# 1618         (Dark Green Other structure Simple as that Cheeky Tanga, Black Other structure Simple as that Cheeky Tanga)
# 1617         (Dark Green Other structure Simple as That Triangle Top, Black Other structure Simple as that Cheeky Tanga)
# 1616    (Dark Green Other structure Simple as That Triangle Top, Dark Green Other structure Simple as that Cheeky Tanga)
# 535                                (Dark Grey Solid Jade HW Skinny Denim TRS, Light Blue Solid Jade HW Skinny Denim TRS)
# 536                                     (Dark Grey Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 537                                    (Light Blue Solid Jade HW Skinny Denim TRS, Black Solid Jade HW Skinny Denim TRS)
# 2988                  (Red Other structure Simple as that Cheeky Tanga, Red Other structure Simple as That Triangle Top)
# 2989                (Red Other structure Simple as that Cheeky Tanga, Black Other structure Simple as that Cheeky Tanga)
#
#        support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 18                          200                  0.000150       20.140987
# 17                          200                  0.000150       23.014960
# 16                          200                  0.000150       23.419204
# 530                         119                  0.000089       11.983887
# 529                         119                  0.000089       30.357143
# 528                         119                  0.000089       25.265393
# 542                         115                  0.000086       13.466042
# 540                         115                  0.000086       31.944444
# 541                         115                  0.000086       24.416136
# 65247                       107                  0.000080       91.452991
# 65248                       107                  0.000080       19.314079
# 65246                       107                  0.000080       92.241379
# 1618                         98                  0.000074       70.000000
# 1617                         98                  0.000074       84.482759
# 1616                         98                  0.000074       10.548977
# 535                          95                  0.000071       26.388889
# 536                          95                  0.000071       24.234694
# 537                          95                  0.000071       10.932106
# 2988                         85                  0.000064       11.348465
# 2989                         85                  0.000064       65.384615
#
#               lift
# 18       56.182815
# 17       59.091918
# 16       55.323282
# 530      76.642364
# 529      77.943295
# 528      59.684542
# 542      86.121414
# 540      82.018761
# 541      68.108244
# 65247  1878.114706
# 65248   482.060615
# 65246  1879.822894
# 1618    726.610903
# 1617    777.621785
# 1616     76.329010
# 535      62.338582
# 536      67.602116
# 537      69.915748
# 2988     82.113843
# 2989    502.278963

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#                                                    consequent  \
# 251237                White Placement print BOULEVARD TEE TVP
# 251236                              Black Solid CHARLIE SKIRT
# 251235                      Black Contrast Heavy jsy long leg
# 251234                                  Black Solid Tilly (1)
# 251233                             Black Solid Luna skinny RW
# 251232  Off White All over pattern Tiblisi paperwaist tapered
# 251230                            Grey Solid Ida Panel Jogger
# 251229                     Blue Denim Skinny H.W Ankle Queens
# 251228                Dark Blue Denim Skinny H.W Ankle Queens
# 251227                           Dark Red Solid Siri Cardigan
# 251225              Black All over pattern Stella Pull on TRS
# 251224              Black All over pattern Stella Pull on TRS
# 251223                                        Red Check Enter
# 251222                             Black Melange Benny Shorts
# 251221                               Off White Solid Griezman
# 251220              Black All over pattern Stella Pull on TRS
# 251219                               Blue Denim Boyfriend L.W
# 251218                               Blue Denim Boyfriend L.W
# 251217                            Black Dot Evelyn midi dress
# 630047                      Blue Solid A-band 2pk fabric ears
#
#                                                                                        antecedent  \
# 251237               (Black All over pattern Stella Pull on TRS, Blue All over pattern Julie (1))
# 251236               (Black All over pattern Stella Pull on TRS, Blue All over pattern Julie (1))
# 251235               (Black All over pattern Stella Pull on TRS, Blue All over pattern Julie (1))
# 251234               (Black All over pattern Stella Pull on TRS, Blue All over pattern Julie (1))
# 251233               (Black All over pattern Stella Pull on TRS, Blue All over pattern Julie (1))
# 251232  (Black All over pattern Stella Pull on TRS, Black All over pattern Victoria Pull- On TRS)
# 251230             (Black All over pattern Stella Pull on TRS, Black Solid Daiquiri Pull- On TRS)
# 251229             (Black All over pattern Stella Pull on TRS, Black Solid Daiquiri Pull- On TRS)
# 251228             (Black All over pattern Stella Pull on TRS, Black Solid Daiquiri Pull- On TRS)
# 251227             (Black All over pattern Stella Pull on TRS, Black Solid Daiquiri Pull- On TRS)
# 251225                              (Black Solid Julie (1), Black Solid Victoria RW Pull- On TRS)
# 251224                    (Black Solid Becky softpant, Black All over pattern Waleo HW wide full)
# 251223             (Black All over pattern Stella Pull on TRS, Black Solid Daiquiri Pull- On TRS)
# 251222  (Black All over pattern Stella Pull on TRS, Black All over pattern Victoria Pull- On TRS)
# 251221  (Black All over pattern Stella Pull on TRS, Black All over pattern Victoria Pull- On TRS)
# 251220                                 (Black Solid Latte slacks (1), Black Solid Luna skinny RW)
# 251219  (Black All over pattern Stella Pull on TRS, Black All over pattern Victoria Pull- On TRS)
# 251218             (Black All over pattern Stella Pull on TRS, Black Solid Daiquiri Pull- On TRS)
# 251217  (Black All over pattern Stella Pull on TRS, Black All over pattern Victoria Pull- On TRS)
# 630047                               (Grey All over pattern Pria tee, White Front print Pria tee)
#
#         support_itemset_absolute  support_itemset_relative  confidence_pct  \
# 251237                         1              7.502934e-07        6.666667
# 251236                         1              7.502934e-07        6.666667
# 251235                         1              7.502934e-07        6.666667
# 251234                         1              7.502934e-07        6.666667
# 251233                         1              7.502934e-07        6.666667
# 251232                         1              7.502934e-07        5.555556
# 251230                         1              7.502934e-07        6.666667
# 251229                         1              7.502934e-07        6.666667
# 251228                         1              7.502934e-07        6.666667
# 251227                         1              7.502934e-07        6.666667
# 251225                         1              7.502934e-07        5.000000
# 251224                         1              7.502934e-07        6.666667
# 251223                         1              7.502934e-07        6.666667
# 251222                         1              7.502934e-07        5.555556
# 251221                         1              7.502934e-07        5.555556
# 251220                         1              7.502934e-07        5.000000
# 251219                         1              7.502934e-07        5.555556
# 251218                         1              7.502934e-07        6.666667
# 251217                         1              7.502934e-07        5.555556
# 630047                         1              7.502934e-07        5.000000
#
#                 lift
# 251237     84.062567
# 251236     48.474704
# 251235     34.640988
# 251234     29.189926
# 251233     15.898038
# 251232    185.576720
# 251230    190.674106
# 251229    158.668095
# 251228    154.798142
# 251227    197.893393
# 251225    343.508247
# 251224    458.010997
# 251223    126.753400
# 251222    170.218646
# 251221    164.179847
# 251220    343.508247
# 251219    110.350389
# 251218    132.420467
# 251217    168.667679
# 630047  66640.600000

# %%
# parameters for apriori or fpgrowth algorithms
supp = 0.001 
conf = 5 
zmin = 2 # minimum length
zmax = 2 # maximum length 
report = 'asCl'
algo = 'ap' # 'fp' or 'ap'

# run apriori
if algo == 'ap':
    result = arules(array_type_old, zmin=zmin, zmax=zmax, supp=supp, conf=conf, report=report)
elif algo == 'fp':
    result = fpgrowth(array_type_old, zmin=zmin, zmax=zmax, supp=supp, report=report)

if algo == 'ap':
    colnames = ['consequent', 'antecedent'] + [report_colnames.get(k, k) for k in list(report)]
elif algo == 'fp':
    colnames = ['itemset'] + [report_colnames.get(k, k) for k in list(report)]
df_result = pd.DataFrame(result, columns=colnames)
df_result = df_result.sort_values('support_itemset_absolute', ascending=False)
print(df_result.shape)
# Out:
# (1711, 6)

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.head(20))
# Out:
#           consequent          antecedent  support_itemset_absolute  \
# 0           Trousers          (Sweater,)                     77316
# 1            Sweater         (Trousers,)                     77316
# 153  Swimwear bottom       (Bikini top,)                     58501
# 154       Bikini top  (Swimwear bottom,)                     58501
# 3              Dress         (Trousers,)                     54380
# 2           Trousers            (Dress,)                     54380
# 6           Trousers          (T-shirt,)                     53242
# 7            T-shirt         (Trousers,)                     53242
# 20          Trousers           (Blouse,)                     49167
# 21            Blouse         (Trousers,)                     49167
# 12          Trousers              (Top,)                     48090
# 13               Top         (Trousers,)                     48090
# 14           Sweater              (Top,)                     37105
# 15               Top          (Sweater,)                     37105
# 25            Blouse            (Dress,)                     37013
# 24             Dress           (Blouse,)                     37013
# 8            Sweater          (T-shirt,)                     36068
# 9            T-shirt          (Sweater,)                     36068
# 18           T-shirt              (Top,)                     34764
# 19               Top          (T-shirt,)                     34764
#
#      support_itemset_relative  confidence_pct       lift
# 0                    0.058010       30.332966   1.113474
# 1                    0.058010       21.294422   1.113474
# 153                  0.043893       78.587069  13.959802
# 154                  0.043893       77.969106  13.959802
# 3                    0.040801       14.977374   0.775613
# 2                    0.040801       21.129032   0.775613
# 6                    0.039947       29.815592   1.094482
# 7                    0.039947       14.663946   1.094482
# 20                   0.036890       31.165102   1.144021
# 21                   0.036890       13.541606   1.144021
# 12                   0.036082       30.666905   1.125733
# 13                   0.036082       13.244978   1.125733
# 14                   0.027840       23.661790   1.237263
# 15                   0.027840       14.557203   1.237263
# 25                   0.027771       14.381185   1.214950
# 24                   0.027771       23.461141   1.214950
# 8                    0.027062       20.198128   1.056150
# 9                    0.027062       14.150362   1.056150
# 18                   0.026083       22.168939   1.654638
# 19                   0.026083       19.467887   1.654638

# %%
with pd.option_context('display.max_colwidth', 400):
    display(df_result.tail(20))
# Out:
#              consequent        antecedent  support_itemset_absolute  \
# 1666         Hat/beanie       (Headband,)                         1
# 1688    Hair/alice band  (Sleeping sack,)                         1
# 1689          Dungarees  (Sleeping sack,)                         1
# 1686   Underwear Tights  (Sleeping sack,)                         1
# 1664  Other accessories       (Headband,)                         1
# 1663               Coat       (Headband,)                         1
# 1660                Bag       (Headband,)                         1
# 1672              Dress  (Sleeping sack,)                         1
# 1659           Cardigan       (Headband,)                         1
# 1674              Skirt  (Sleeping sack,)                         1
# 1675   Underwear bottom  (Sleeping sack,)                         1
# 1676    Swimwear bottom  (Sleeping sack,)                         1
# 1677         Bikini top  (Sleeping sack,)                         1
# 1656             Jacket       (Headband,)                         1
# 1680             Hoodie  (Sleeping sack,)                         1
# 1654              Shirt       (Headband,)                         1
# 1683  Jumpsuit/Playsuit  (Sleeping sack,)                         1
# 1652             Blouse       (Headband,)                         1
# 1685              Boots  (Sleeping sack,)                         1
# 1710           Dog Wear       (Dog wear,)                         1
#
#       support_itemset_relative  confidence_pct        lift
# 1666              7.502934e-07        6.666667   11.194927
# 1688              7.502934e-07        7.142857   12.795814
# 1689              7.502934e-07        7.142857   24.778984
# 1686              7.502934e-07        7.142857    7.402866
# 1664              7.502934e-07        6.666667    8.797439
# 1663              7.502934e-07        6.666667    6.170854
# 1660              7.502934e-07        6.666667    3.828929
# 1672              7.502934e-07        7.142857    0.369897
# 1659              7.502934e-07        6.666667    2.006915
# 1674              7.502934e-07        7.142857    1.145756
# 1675              7.502934e-07        7.142857    1.138848
# 1676              7.502934e-07        7.142857    1.268820
# 1677              7.502934e-07        7.142857    1.278877
# 1656              7.502934e-07        6.666667    1.236816
# 1680              7.502934e-07        7.142857    1.507153
# 1654              7.502934e-07        6.666667    1.021453
# 1683              7.502934e-07        7.142857    4.385115
# 1652              7.502934e-07        6.666667    0.563213
# 1685              7.502934e-07        7.142857    5.728435
# 1710              7.502934e-07        5.555556  207.409275
